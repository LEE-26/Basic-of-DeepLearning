# %% [markdown]
# # 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 경로 지정

# %%
# %cd "/content/drive/MyDrive/project/colab_code/딥러닝기초"
# Out:
# /content/drive/MyDrive/project/colab_code/딥러닝기초

# %% [markdown]
# # commit

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/project/colab_code/딥러닝기초/.git/

# %%
# !git config --global user.email "tiffk79@gmail.com"
# !git config --global user.name "Leeyh"

# %%
# staging
# !git add .

# %%
# commit 
# !git commit -m "Basic of DeepLearnig 1"
# Out:
# [master (root-commit) 897adb1] Basic of DeepLearnig 1
#  4 files changed, 4 insertions(+)
#  create mode 100644 ConvLayer.ipynb
#  create mode 100644 "NLP \341\204\213\341\205\265\341\206\270\341\204\206\341\205\256\341\206\253.ipynb"
#  create mode 100644 UploadTogithub.ipynb
#  create mode 100644 "\341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274 \341\204\202\341\205\246\341\204\220\341\205\263\341\204\213\341\205\257\341\204\217\341\205\263\341\204\213\341\205\264 \341\204\213\341\205\247\341\206\253\341\204\211\341\205\241\341\206\253.ipynb"

# %%
# !git remote rm origin

# %%
# 원격 저장소 주소 지정
# !git remote add origin "https://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@github.com/LEE-26/Basic-of-DeepLearning.git"

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
