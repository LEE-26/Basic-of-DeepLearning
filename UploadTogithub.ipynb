# %% [markdown]
# # 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 경로 지정

# %%
# %cd "/content/drive/MyDrive/project/colab_code/딥러닝기초"
# Out:
# /content/drive/MyDrive/project/colab_code/딥러닝기초

# %% [markdown]
# # commit

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/project/colab_code/딥러닝기초/.git/

# %%
# !git config --global user.email "tiffk79@gmail.com"
# !git config --global user.name "Leeyh"

# %%
# staging
# !git add .

# %%
# commit 
# !git commit -m "Basic of DeepLearnig 1"
# Out:
# [master ce9663f] Basic of DeepLearnig 1
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite UploadTogithub.ipynb (97%)

# %%
# !git remote rm origin

# %%
# !git push -f origin master
# Out:
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 110.61 KiB | 5.03 MiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), done.
# To https://github.com/LEE-26/Basic-of-DeepLearning.git
#  + 8094a6b...ce9663f master -> master (forced update)

# %% [markdown]
# ### 두 번째 commit

# %%
# !git config --global user.email "tiffk79@gmail.com"
# !git config --global user.name "Leeyh"

# %%
# !git add .

# %%
# !git commit -m "Basic of DeepLearnig 2"
# Out:
# [master 7489369] Basic of DeepLearnig 2
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite UploadTogithub.ipynb (96%)
#  create mode 100644 "\341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274 \341\204\213\341\205\265\341\206\253\341\204\200\341\205\251\341\206\274\341\204\214\341\205\265\341\204\202\341\205\263\341\206\274.ipynb"

# %%
# !git push -f origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 4.46 KiB | 913.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/LEE-26/Basic-of-DeepLearning.git
#    ce9663f..7489369  master -> master

# %% [markdown]
# ### 세 번째 커밋

# %%
! git add .

# %%
! git commit -m "Basic of DeepLearning 3"
# Out:
# [master 7859f14] Basic of DeepLearning 3
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Numpy Tutorial.ipynb
#  rewrite UploadTogithub.ipynb (90%)

# %%
# !git remote rm origin

# %%
# 원격 저장소 주소 지정
# !git remote add origin "https://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@github.com/LEE-26/Basic-of-DeepLearning.git"

# %%
# !git push -f origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 12.05 KiB | 2.01 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/LEE-26/Basic-of-DeepLearning.git
#    7489369..7859f14  master -> master

# %% [markdown]
# # 네 번째 커밋

# %%
! git add .

# %%
! git commit -m "Basic of DeepLearning 4"
# Out:
# [master 307420e] Basic of DeepLearning 4
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite UploadTogithub.ipynb (94%)
#  create mode 100644 Visualization-Matplotlib.ipynb

# %%
# 원격 저장소 주소 지정
# !git remote add origin "https://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@github.com/LEE-26/Basic-of-DeepLearning.git"

# %%
# !git push -f origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 853.62 KiB | 11.38 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/LEE-26/Basic-of-DeepLearning.git
#    7859f14..307420e  master -> master
