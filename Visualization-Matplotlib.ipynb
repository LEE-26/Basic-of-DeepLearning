# %% [markdown]
# # Matplotlib
# - Matplotlib 은 Python 에서 사용할 수 있는 시각화 라이브러리로 주로 2D 그래프를 위한 패키지이다.
# - 파이썬에서 매트랩과 유사한 인터페이스를 지원하기 위해 시작되었고, IPython 과 협력으로 대화형 시각화를 지원한다.

# %% [markdown]
# ## 라이브러리 import

# %%
import matplotlib 
import matplotlib.pyplot as plt 
import numpy as np

print("Matplotlib Version :" , matplotlib.__version__)
print("Numpy Version :", np.__version__)
# Out:
# Matplotlib Version : 3.2.2
# Numpy Version : 1.19.5

# %% [markdown]
# ## 간략하게 graph 그려보기

# %%
data = np.arange(10)
plt.plot(data) # 하나만 들어가면 y 값으로 생각
plt.show()

# %% [markdown]
# ## figure 와 subplot
# - matplotlib 에서 그래프는 figure 라는 큰 틀에 ax 라는 subplot 을 추가해서 만든다.

# %%
# figure instance 생성
fig = plt.figure()
plt.show()

# %%
# 빈 subplot 생성
# fig 라는 큰 틀을 만들어 
# fig 안에 subplot 을 만든다
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
# figure size 조정하기 
fig = plt.figure(figsize = (10, 5)) 
ax = fig.add_subplot()
plt.show()

# %%
# 여러개의 subplot 만들기 
fig = plt.figure(figsize = (10, 5))
ax1 = fig.add_subplot(2, 2, 1) # 2행 2열
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
# 여러개의 subplot 만들기 
# 콤마를 제거해도 가능
fig = plt.figure(figsize = (10, 5))
ax1 = fig.add_subplot(221) # 2행 2열
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# %% [markdown]
# ## plt 로 graph 그리기

# %%
fig = plt.figure()
ax = fig.add_subplot()

data = np.array([1, 2, 3])

plt.plot(data)
plt.show()

# %%
# 2개의 graph 를 순차적으로 그리기 

fig = plt.figure() 

x = np.arange(100)
y1 = x
y2 = x ** 2

fig.add_subplot(211)
plt.plot(x, y1)

fig.add_subplot(212)
plt.plot(x, y2)
plt.show()

# %%
# 같은 graph 를 subplot 객체 ax 에 그리기 
fig = plt.figure() 

x = np.arange(100)
y1 = x
y2 = x ** 2

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.plot(x, y1)
ax2.plot(x, y2)

# %% [markdown]
# ## plot 종류별 사용법

# %% [markdown]
# ### bar plot
# - barplot 은 ax.bar 와 같이 사용하며 다음과 같은 인자를 받는다.
#     - x : x축에 사용될 값
#     - height : y 축에 사용될 값
#     - width : 각 bar 의 width
#     - bottom : y 축의 base 값
#     - align : 정렬 (center or edge)

# %%
# bar plot 
fig = plt.figure() 
ax = fig.add_subplot()

ax.bar([0,1,2,3,4], [3,2,5,4,6]) # 범주 , 빈도
plt.show()

# %%
# width 조정
fig = plt.figure() 
ax = fig.add_subplot()

ax.bar([0,1,2,3,4], [3,2,5,4,6], width = 0.5) # 범주 , 빈도
plt.show()

# %%
# bottom 조정 

fig = plt.figure() 
ax = fig.add_subplot()

# y 값이 2 부터 시작
ax.bar([0,1,2,3,4], [3,2,5,4,6], bottom = 2) 
plt.show()

# %%
# align 조정

fig = plt.figure() 
ax = fig.add_subplot()

ax.bar([0,1,2,3,4], [3,2,5,4,6], align = "edge") 
plt.show()

# %% [markdown]
# ### histogram plot

# %% [markdown]
# - histogram plot 은 data 의 분포를 나타낼 때 사용하며, 주로 다음과 같은 인자를 사욯한다.
#     - x : 입력 data
#     - bins : histogram 을 나타낼 x 축의 구간 (정수 입력시 구간의 갯수, list 와 같은 sequence 입력시는 sequence 값이 구간으로 설정됨)
#     - range : x 축 범위 (x.min, x.max) 로 표현
#     - density : 확률 분포로 나타낼 것인지 여부

# %%
# histogram 
np.random.seed(111)

fig = plt.figure()
ax = fig.add_subplot() 
ax.hist(np.random.randn(500)) 
plt.show()

# %%
# bins 
np.random.seed(111)

fig = plt.figure()
ax = fig.add_subplot() 
ax.hist(np.random.randn(500), bins = 50) # 더욱 촘촘하게
plt.show()

# %%
# bins
fig = plt.figure()
ax = fig.add_subplot() 
ax.hist(np.random.randn(500),[-3, -2, -1, 0, 1, 2, 3])
# ax.hist(np.random.randn(500) , np.linspace(-2, 2, num = 40)) 
plt.show()

# %%
# range
np.random.seed(111) 

fig = plt.figure()
ax = fig.add_subplot() 

ax.hist(np.random.randn(500), [-2, -1, 0, 1, 2, 3])
plt.show()

# %%
# density 
np.random.seed(111) 

fig = plt.figure()
ax = fig.add_subplot() 

ax.hist(np.random.randn(500), density = True) # 확률분포
plt.show()

# %% [markdown]
# ### line plot
# - line plot 은 가장 기본적인 plot 으로 x, y data 의 관계를 선으로 표시해주는 graph 입니다.
#     - x : x data
#     - y : y data
#     - fmt : 색상, 마커, 선 스타일 등 설정(자세한 내용은 아래 링크 참조)
# <br>
# <br>
# https://matplotlib.org./stable/gallery/color/named_colors.html

# %%
# !pip install pykrx
from pykrx import stock
# Out:
# Collecting pykrx
#   Downloading pykrx-1.0.29-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 3.7 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pykrx) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pykrx) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pykrx) (2.23.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from pykrx) (1.1.0)
# Collecting datetime
#   Downloading DateTime-4.3-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 6.4 MB/s
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from datetime->pykrx) (2018.9)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 23.8 MB/s
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated->pykrx) (1.13.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pykrx) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pykrx) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pykrx) (2021.10.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from zope.interface->datetime->pykrx) (57.4.0)
# Installing collected packages: zope.interface, deprecated, datetime, pykrx
# Successfully installed datetime-4.3 deprecated-1.2.13 pykrx-1.0.29 zope.interface-5.4.0

# %%
Kepco = stock.get_market_ohlcv_by_date(fromdate="20110101", todate="20211210", ticker="015760")

# %%
Kepco
# Out:
#                시가     고가     저가     종가      거래량
# 날짜
# 2011-01-03  30400  30450  29800  30050  1261721
# 2011-01-04  30050  30050  29700  29900  1718372
# 2011-01-05  29800  29850  29200  29250  2324148
# 2011-01-06  29350  29650  29050  29050  1930250
# 2011-01-07  29000  29050  28650  28950  2077771
# ...           ...    ...    ...    ...      ...
# 2021-12-06  21650  21800  21300  21650   967295
# 2021-12-07  21700  22000  21600  21900   943397
# 2021-12-08  22000  22450  21950  22200  1645576
# 2021-12-09  22200  22400  22100  22350  1625508
# 2021-12-10  22250  22300  22050  22150   810107
#
# [2697 rows x 5 columns]

# %%
fig = plt.figure(figsize = (15, 5))
ax = fig.add_subplot()

ax.plot(Kepco["종가"])
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %%
# format 변경
fig = plt.figure(figsize = (15, 5))
ax = fig.add_subplot()

ax.plot(Kepco["종가"], "mo--")
plt.show()

# %% [markdown]
# ### scatter plot

# %% [markdown]
# - scatter plot 은 line plot 과 유사하게 x, y, data 의 관계를 점으로 표시해준다
# - scatter plot 은 data 간의 유사도와 같은 상관관계를 파악할 때 많이 사용한다
# - iris dataset 을 이용하여 scatter plot 을 그려본다
# - 링크에 접속하여 iris.csv 파일을 다운받고 현재 directory 에 복사한다. colab 을 사용하는 경우에는 iris.csv 파일을 upload 해야한다.

# %%
import pandas as pd

# %%
iris_df = pd.read_csv("./Iris.csv")
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = plt.figure(figsize = (15, 5))
ax = fig.add_subplot()

ax.scatter(x = iris_df["SepalLengthCm"] ,
               y = iris_df["SepalWidthCm"])

plt.show()

# %% [markdown]
# ## 한 subplot에 여러개 graph 그리기

# %%
# 3개의 graph 동시에 그리기
fig = plt.figure() 

ax = fig.add_subplot()

ax.plot([1,2,3,4])
ax.plot([1,1.5,2])
ax.plot([1,2.5,4])

plt.show()

# %%
# line plot 과 bar plot 동시에 그리기

fig = plt.figure()

ax = fig.add_subplot()

ax.plot([1,2,3], [1,2,3])
ax.bar([1,2,3], [1,2,3], color = "red")

plt.show()

# %%
fig = plt.figure(figsize = (7, 7))

ax = fig.add_subplot()

for species in iris_df["Species"].unique() : 
    iris_sub = iris_df[iris_df["Species"] == species]
    ax.scatter(x=iris_sub["PetalLengthCm"],
               y=iris_sub["PetalWidthCm"])
plt.show()

# %% [markdown]
# ## 여러개 subplot 한 번에 만들기

# %%
# plt.subplots 활용 
fig, axes = plt.subplots(2, 3, figsize = (10, 5)) 
axes[0, 1].plot([1,2,3])
axes[1, 2].plot([1,2,3])
plt.show()

# %%
np.random.seed(100)

fig, axes = plt.subplots(2, 2, figsize = (10, 5))
axes[0, 0].hist(np.random.randn(200), bins = 20)
axes[0, 1].bar(np.arange(10), np.random.randn(10) * 10 + 10)
axes[1, 0].scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
axes[1,1].plot(np.random.randn(50).cumsum()*5 + 20)

plt.show()

# %%
# 축 눈금 공유 sharey = True

np.random.seed(100)

fig, axes = plt.subplots(2, 2, figsize = (10, 5), sharey = True)
axes[0, 0].hist(np.random.randn(200), bins = 20)
axes[0, 1].bar(np.arange(10), np.random.randn(10) * 10 + 10)
axes[1, 0].scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
axes[1,1].plot(np.random.randn(50).cumsum()*5 + 20)

plt.show()

# %%
# subplot 간격 조정 

np.random.seed(100)

fig, axes = plt.subplots(2, 2, figsize = (10, 5), sharex = True, sharey = True)
for i in range(2) : 
    for j in range(2) : 
        axes[i, j].hist(np.random.randn(500), bins = 50)

plt.subplots_adjust(wspace = 0, hspace = 0) # subplot 간격 조정

plt.show()

# %% [markdown]
# ## 색상 지정하기

# %%
np.random.seed(100)

fig, axes = plt.subplots(2, 2, figsize = (10, 5), sharey = True)
axes[0, 0].hist(np.random.randn(200), bins = 20, color = "r")
axes[0, 1].bar(np.arange(10), np.random.randn(10) * 10 + 10, color = "seagreen")
axes[1, 0].scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30), color = "#0000ff") # RGB 표현
axes[1,1].plot(np.random.randn(50).cumsum()*5 + 20, color = "brown")

plt.show()

# %% [markdown]
# ## label 지정

# %%
fig = plt.figure(figsize = (7, 7))

ax = fig.add_subplot()

for species in iris_df["Species"].unique() : 
    iris_sub = iris_df[iris_df["Species"] == species]
    ax.scatter(x=iris_sub["PetalLengthCm"],
               y=iris_sub["PetalWidthCm"],
               label = species)
    
plt.legend()
plt.show()

# %% [markdown]
# ## 제목, 축이름, 눈금 설정하기

# %%
fig = plt.figure(figsize = (7, 7))

ax = fig.add_subplot()

for species in iris_df["Species"].unique() : 
    iris_sub = iris_df[iris_df["Species"] == species]
    ax.scatter(x=iris_sub["PetalLengthCm"],
               y=iris_sub["PetalWidthCm"],
               label = species)
    
ax.set_title("Iris")
xticks = np.arange(1, 7.5, 0.5)
ax.set_xticks(xticks)
ax.set_xlabel("PetalLengthCM")
ax.set_ylabel("PetalWidthCM")
    
plt.legend()
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Image Data Visualization
# - Image data 는 plt.imshow() 를 이용하여 화면에 출력 가능하다.
#     - X : image data, gray scale 의 경우는 2차원 RGB 나 RGBA 의 경우는 3차원의 data 가 필요하다. 이 때 data 의 shape 은 (height, width, channel) 순서이다.
#     - cmap : colormap
#     https://matplotlib.org/stable/tutorials/colors/colormaps/html

# %% [markdown]
# - 임의의 image 를 가져와서 화면에 출력

# %%
from PIL import Image

# %%
image = Image.open("./dog.jpg")

fig = plt.figure() 

ax = fig.add_subplot()
ax.imshow(image)

plt.show()

# %% [markdown]
# Oxford IIIT Pet dataset 을 다운받아서 화면에 출력

# %%
import os 
import random
import xml.etree.ElementTree as et 
from matplotlib.patches import Rectangle # 사각형

# %%
## google drive 에서 압축된 dataset download
import gdown
url = "https://drive.google.com/uc?id=1dIR9ANjUsV9dWa0pS9J0c2KUGMfpIRG0"
fname = "oxford_pet.zip"
gdown.download(url, fname, quiet = False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dIR9ANjUsV9dWa0pS9J0c2KUGMfpIRG0
# To: /content/oxford_pet.zip
# 100%|██████████| 811M/811M [00:04<00:00, 193MB/s]
# 'oxford_pet.zip'

# %%
## 압축풀기
# !unzip -q oxford_pet.zip -d oxford_pet

# %%
cur_dir = os.getcwd()
data_dir = os.path.join(cur_dir, 'oxford_pet')
image_dir = os.path.join(data_dir, 'images')
bbox_dir = os.path.join(data_dir, 'annotations', 'xmls')
seg_dir = os.path.join(data_dir, 'annotations', 'trimaps')

# %%
image_files = [fname for fname in os.listdir(image_dir) if os.path.splitext(fname)[-1] == '.jpg']
bbox_files = [fname for fname in os.listdir(bbox_dir) if os.path.splitext(fname)[-1] == '.xml']
seg_files = [fname for fname in os.listdir(seg_dir) if os.path.splitext(fname)[-1] == '.png']

# %%
rnd_idx = random.randint(1, len(bbox_files))

bbox_name = bbox_files[rnd_idx]
bbox_path = os.path.join(bbox_dir, bbox_name)
tree = et.parse(bbox_path)

width = float(tree.find('./size/width').text)
height = float(tree.find('./size/height').text)
xmin = float(tree.find('./object/bndbox/xmin').text)
xmax = float(tree.find('./object/bndbox/xmax').text)
ymin = float(tree.find('./object/bndbox/ymin').text)
ymax = float(tree.find('./object/bndbox/ymax').text)

rect_x = xmin
rect_y = ymin
rect_w = xmax-xmin
rect_h = ymax-ymin

fname = os.path.splitext(bbox_name)[0]+'.jpg'
fpath = os.path.join(image_dir, fname)
image = Image.open(fpath)
# image = np.array(image)

bbox_name = os.path.splitext(fname)[0]+'.xml'

fig, ax = plt.subplots(1, 1)
rect = Rectangle((rect_x, rect_y), rect_w, rect_h, fill=False, color='red')
ax.add_patch(rect)
ax.imshow(image)
plt.show()

# %%
sname = os.path.splitext(bbox_name)[0]+'.png'
spath = os.path.join(seg_dir, sname)
seg = Image.open(spath)

fig, ax = plt.subplots(1, 2, figsize=(15,8))
ax[0].imshow(image)
ax[1].imshow(seg)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.imshow(image)
ax.imshow(seg, alpha=0.5)
plt.show()
